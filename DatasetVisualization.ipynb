# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/FDSML_/
# Out:
# /content/drive/MyDrive/FDSML_

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn import svm
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from yellowbrick.features import Manifold

# %%
# Read the data
data = pd.read_csv('ExpImpDev.csv')

diseaseList = np.empty((0,12))
with open('disease.txt') as f:
    lines = f.readlines()
    for el in lines:
      el = el.replace('\n', '')
      diseaseList = np.append(diseaseList, el)
print(diseaseList)
# Out:
# ['Esophagitis' 'Enteritis' 'Asthma' 'Coronary heart disease' 'Pneumonia'
#  'Rhinitis' 'Thyroiditis' 'Traumatic brain injury' 'Dermatitis'
#  'External otitis' 'Conjunctivitis' 'Mastitis']

# %%
list1 = ['Asthma', 'Enteritis', 'Esophagitis']
X1 = data[data['disease_tag'].isin(list1)]
X1 = X1.to_numpy()
y1 = X1[:, 118]
le = LabelEncoder()
le.fit(list1)
X1 = X1[:, :118]

le = LabelEncoder()
le.fit(list1)
target = le.transform(y1)
viz = Manifold(manifold='tsne', classes=list1, projection=3)
viz.fit_transform(X1, target)
viz.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,

# %%
list2 = ['Coronary heart disease', 'Pneumonia', 'Rhinitis']
X2 = data[data['disease_tag'].isin(list2)]
X2 = X2.to_numpy()
y2 = X2[:, 118]
le = LabelEncoder()
le.fit(list2)
X2 = X2[:, :118]

le = LabelEncoder()
le.fit(list2)
target = le.transform(y2)
viz = Manifold(manifold='tsne', classes=list2, projection=3)
viz.fit_transform(X2, target)
viz.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,

# %%
list3 = ['Thyroiditis', 'Traumatic brain injury', 'Dermatitis']
X3 = data[data['disease_tag'].isin(list3)]
X3 = X3.to_numpy()
y3 = X3[:, 118]
le = LabelEncoder()
le.fit(list3)
X3 = X3[:, :118]

le = LabelEncoder()
le.fit(list3)
target = le.transform(y3)
viz = Manifold(manifold='tsne', classes=list3, projection=3)
viz.fit_transform(X3, target)
viz.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,

# %%
list4 = ['External otitis', 'Conjunctivitis', 'Mastitis']
X4 = data[data['disease_tag'].isin(list4)]
X4 = X4.to_numpy()
y4 = X4[:, 118]
le = LabelEncoder()
le.fit(list4)
X4 = X4[:, :118]

le = LabelEncoder()
le.fit(list4)
target = le.transform(y4)
viz = Manifold(manifold='tsne', classes=list4, projection=3)
viz.fit_transform(X4, target)
viz.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,

# %%
X = data.to_numpy()
y = X[:, 118]
le = LabelEncoder()
le.fit(diseaseList)
X = X[:, :118]

# %%
#Tring to vizualize dataset
le = LabelEncoder()
le.fit(diseaseList)
target = le.transform(y)
viz = Manifold(manifold='tsne', classes=diseaseList, projection=3)
viz.fit_transform(X, target)
viz.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,
